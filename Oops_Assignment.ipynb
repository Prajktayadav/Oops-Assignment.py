# %%
#1.Bank Account Create a class representing a bank account with attributes like account number, account holder name, and balance. Implement methods to deposit and withdraw money from the account


class BankAccount:
    def __init__(self, account_number, account_holder, balance=0.0):
        self.account_number = account_number
        self.account_holder = account_holder
        self.balance = balance

    def deposit(self, amount):
        if amount > 0:
            self.balance += amount
            print(f"Deposited ${amount}. New balance: ${self.balance}")
        else:
            print("Invalid deposit amount. Please enter a positive value.")

    def withdraw(self, amount):
        if amount > 0:
            if amount <= self.balance:
                self.balance -= amount
                print(f"Withdrew ${amount}. New balance: ${self.balance}")
            else:
                print("Insufficient funds. Withdrawal amount exceeds the current balance.")
        else:
            print("Invalid withdrawal amount. Please enter a positive value.")

    def get_balance(self):
        return self.balance

    def display_account_info(self):
        print(f"Account Number: {self.account_number}")
        print(f"Account Holder: {self.account_holder}")
        print(f"Balance: ${self.balance}")


account1 = BankAccount(account_number="123456789", account_holder="Omkar Yadav", balance=1000.0)

account1.display_account_info()
account1.deposit(500.0)
account1.withdraw(200.0)
account1.display_account_info()
# Out:
# Account Number: 123456789
# Account Holder: Omkar Yadav
# Balance: $1000.0
# Deposited $500.0. New balance: $1500.0
# Withdrew $200.0. New balance: $1300.0
# Account Number: 123456789
# Account Holder: Omkar Yadav
# Balance: $1300.0

# %%
#2.Employee Management Create a class representing an employee with attributes like employee ID, name, and salary. Implement methods to calculate the yearly bonus and display employee details

class Employee:
    def __init__(self, employee_id, name, salary):
        self.employee_id = employee_id
        self.name = name
        self.salary = salary

    def calculate_yearly_bonus(self, bonus_percentage):
        if bonus_percentage >= 0:
            bonus_amount = (bonus_percentage / 100) * self.salary
            return bonus_amount
        else:
            print("Invalid bonus percentage. Please enter a non-negative value.")

    def display_employee_details(self):
        print(f"Employee ID: {self.employee_id}")
        print(f"Name: {self.name}")
        print(f"Salary: ${self.salary}")
        print("------------------------")

employee1 = Employee(employee_id="E001", name="Prajkta", salary=50000.0)

employee1.display_employee_details()

bonus_percentage = 10
bonus_amount = employee1.calculate_yearly_bonus(bonus_percentage)

if bonus_amount is not None:
    print(f"Yearly Bonus: ${bonus_amount}")
else:
    print("Error calculating bonus.")

employee1.display_employee_details()
# Out:
# Employee ID: E001
# Name: Prajkta
# Salary: $50000.0
# ------------------------
# Yearly Bonus: $5000.0
# Employee ID: E001
# Name: Prajkta
# Salary: $50000.0
# ------------------------

# %%
#3.Vehicle Rental Create a class representing a vehicle rental system. Implement methods to rent a vehicle, return a vehicle, and display available vehicles

class Vehicle:
    def __init__(self, vehicle_id, vehicle_type, is_rented=False):
        self.vehicle_id = vehicle_id
        self.vehicle_type = vehicle_type
        self.is_rented = is_rented

class VehicleRentalSystem:
    def __init__(self):
        self.vehicles = []

    def add_vehicle(self, vehicle):
        self.vehicles.append(vehicle)

    def rent_vehicle(self, vehicle_id):
        for vehicle in self.vehicles:
            if vehicle.vehicle_id == vehicle_id:
                if not vehicle.is_rented:
                    vehicle.is_rented = True
                    print(f"Vehicle {vehicle_id} rented successfully.")
                else:
                    print(f"Vehicle {vehicle_id} is already rented.")
                return
        print(f"Vehicle {vehicle_id} not found.")

    def return_vehicle(self, vehicle_id):
        for vehicle in self.vehicles:
            if vehicle.vehicle_id == vehicle_id:
                if vehicle.is_rented:
                    vehicle.is_rented = False
                    print(f"Vehicle {vehicle_id} returned successfully.")
                else:
                    print(f"Vehicle {vehicle_id} is not currently rented.")
                return
        print(f"Vehicle {vehicle_id} not found.")

    def display_available_vehicles(self):
        print("Available Vehicles:")
        for vehicle in self.vehicles:
            if not vehicle.is_rented:
                print(f"ID: {vehicle.vehicle_id}, Type: {vehicle.vehicle_type}, Status: Available")
        print("------------------------")

vehicle1 = Vehicle(vehicle_id="V001", vehicle_type="Car")
vehicle2 = Vehicle(vehicle_id="V002", vehicle_type="Bike")
vehicle3 = Vehicle(vehicle_id="V003", vehicle_type="Scooter")

rental_system = VehicleRentalSystem()
rental_system.add_vehicle(vehicle1)
rental_system.add_vehicle(vehicle2)
rental_system.add_vehicle(vehicle3)

rental_system.display_available_vehicles()

rental_system.rent_vehicle("V001")
rental_system.rent_vehicle("V002")

rental_system.display_available_vehicles()

rental_system.return_vehicle("V001")

rental_system.display_available_vehicles()
# Out:
# Available Vehicles:
# ID: V001, Type: Car, Status: Available
# ID: V002, Type: Bike, Status: Available
# ID: V003, Type: Scooter, Status: Available
# ------------------------
# Vehicle V001 rented successfully.
# Vehicle V002 rented successfully.
# Available Vehicles:
# ID: V003, Type: Scooter, Status: Available
# ------------------------
# Vehicle V001 returned successfully.
# Available Vehicles:
# ID: V001, Type: Car, Status: Available
# ID: V003, Type: Scooter, Status: Available
# ------------------------

# %%
#4. Library Catalog Create classes representing a library and a book. Implement methods to add books to the library, borrow books, and display available books


class Book:
    def __init__(self, book_id, title, author, is_available=True):
        self.book_id = book_id
        self.title = title
        self.author = author
        self.is_available = is_available

class Library:
    def __init__(self):
        self.books = []

    def add_book(self, book):
        self.books.append(book)
        print(f"Book '{book.title}' added to the library.")

    def borrow_book(self, book_id):
        for book in self.books:
            if book.book_id == book_id:
                if book.is_available:
                    book.is_available = False
                    print(f"Book '{book.title}' borrowed successfully.")
                else:
                    print(f"Book '{book.title}' is currently not available.")
                return
        print(f"Book with ID {book_id} not found in the library.")

    def display_available_books(self):
        print("Available Books:")
        for book in self.books:
            if book.is_available:
                print(f"ID: {book.book_id}, Title: {book.title}, Author: {book.author}")
        print("------------------------")

book1 = Book(book_id="B001", title="Musafir", author="Achut Godbole")
book2 = Book(book_id="B002", title="Panipat", author="Vishwas Patil")
book3 = Book(book_id="B003", title="Ek Hota Karvhar", author="Veena Gavankar")

library = Library()
library.add_book(book1)
library.add_book(book2)
library.add_book(book3)

library.display_available_books()

library.borrow_book("B001")
library.borrow_book("B002")

library.display_available_books()
# Out:
# Book 'Musafir' added to the library.
# Book 'Panipat' added to the library.
# Book 'Ek Hota Karvhar' added to the library.
# Available Books:
# ID: B001, Title: Musafir, Author: Achut Godbole
# ID: B002, Title: Panipat, Author: Vishwas Patil
# ID: B003, Title: Ek Hota Karvhar, Author: Veena Gavankar
# ------------------------
# Book 'Musafir' borrowed successfully.
# Book 'Panipat' borrowed successfully.
# Available Books:
# ID: B003, Title: Ek Hota Karvhar, Author: Veena Gavankar
# ------------------------

# %%
#5.Product Inventory Create classes representing a product and an inventory system. Implement methods to add products to the inventory, update product quantity, and display available products



class Product:
    def __init__(self, product_id, name, price, quantity):
        self.product_id = product_id
        self.name = name
        self.price = price
        self.quantity = quantity

class Inventory:
    def __init__(self):
        self.products = []

    def add_product(self, product):
        self.products.append(product)
        print(f"Product '{product.name}' added to the inventory.")

    def update_quantity(self, product_id, new_quantity):
        for product in self.products:
            if product.product_id == product_id:
                product.quantity = new_quantity
                print(f"Quantity for product '{product.name}' updated to {new_quantity}.")
                return
        print(f"Product with ID {product_id} not found in the inventory.")

    def display_available_products(self):
        print("Available Products:")
        for product in self.products:
            print(f"ID: {product.product_id}, Name: {product.name}, Price: ${product.price}, Quantity: {product.quantity}")
        print("------------------------")

product1 = Product(product_id="P001", name="Laptop", price=999.99, quantity=10)
product2 = Product(product_id="P002", name="Smartphone", price=599.99, quantity=20)
product3 = Product(product_id="P003", name="Headphones", price=49.99, quantity=50)

inventory_system = Inventory()
inventory_system.add_product(product1)
inventory_system.add_product(product2)
inventory_system.add_product(product3)

inventory_system.display_available_products()

inventory_system.update_quantity("P001", 8)
inventory_system.update_quantity("P002", 15)

inventory_system.display_available_products()
# Out:
# Product 'Laptop' added to the inventory.
# Product 'Smartphone' added to the inventory.
# Product 'Headphones' added to the inventory.
# Available Products:
# ID: P001, Name: Laptop, Price: $999.99, Quantity: 10
# ID: P002, Name: Smartphone, Price: $599.99, Quantity: 20
# ID: P003, Name: Headphones, Price: $49.99, Quantity: 50
# ------------------------
# Quantity for product 'Laptop' updated to 8.
# Quantity for product 'Smartphone' updated to 15.
# Available Products:
# ID: P001, Name: Laptop, Price: $999.99, Quantity: 8
# ID: P002, Name: Smartphone, Price: $599.99, Quantity: 15
# ID: P003, Name: Headphones, Price: $49.99, Quantity: 50
# ------------------------

# %%
#6.Shape Calculation Create a class representing a shape with attributes like length, width, and height. Implement methods to calculate the area and perimeter of the shape


class Shape:
    def __init__(self, length=0, width=0, height=0):
        self.length = length
        self.width = width
        self.height = height

    def calculate_area(self):
        pass

    def calculate_perimeter(self):
        pass


class Rectangle(Shape):
    def calculate_area(self):
        return self.length * self.width

    def calculate_perimeter(self):
        return 2 * (self.length + self.width)


class Square(Rectangle):
    def __init__(self, side_length):
        super().__init__(length=side_length, width=side_length)


class Circle(Shape):
    def __init__(self, radius):
        super().__init__(length=2 * radius)

    def calculate_area(self):
        return 3.14 * (self.length / 2) ** 2

    def calculate_perimeter(self):
        return 3.14 * self.length


rectangle = Rectangle(length=5, width=3)
square = Square(side_length=4)
circle = Circle(radius=2)

print("Rectangle - Area:", rectangle.calculate_area())
print("Rectangle - Perimeter:", rectangle.calculate_perimeter())

print("Square - Area:", square.calculate_area())
print("Square - Perimeter:", square.calculate_perimeter())

print("Circle - Area:", circle.calculate_area())
print("Circle - Perimeter:", circle.calculate_perimeter())
# Out:
# Rectangle - Area: 15
# Rectangle - Perimeter: 16
# Square - Area: 16
# Square - Perimeter: 16
# Circle - Area: 12.56
# Circle - Perimeter: 12.56

# %%
#7.Student Management Create a class representing a student with attributes like student ID, name, and grades. Implement methods to calculate the average grade and display student details


class Student:
    def __init__(self, student_id, name, grades=[]):
        self.student_id = student_id
        self.name = name
        self.grades = grades

    def add_grade(self, grade):
        self.grades.append(grade)

    def calculate_average_grade(self):
        if not self.grades:
            return 0
        return sum(self.grades) / len(self.grades)

    def display_student_details(self):
        print(f"Student ID: {self.student_id}")
        print(f"Name: {self.name}")
        if self.grades:
            print("Grades:", ", ".join(map(str, self.grades)))
            print(f"Average Grade: {self.calculate_average_grade()}")
        else:
            print("No grades available.")
        print("------------------------")


student1 = Student(student_id="S001", name="Tejaswini", grades=[90, 85, 92])
student2 = Student(student_id="S002", name="Omkar")

student1.display_student_details()
student2.display_student_details()

student2.add_grade(88)
student2.add_grade(75)

student2.display_student_details()
# Out:
# Student ID: S001
# Name: Tejaswini
# Grades: 90, 85, 92
# Average Grade: 89.0
# ------------------------
# Student ID: S002
# Name: Omkar
# No grades available.
# ------------------------
# Student ID: S002
# Name: Omkar
# Grades: 88, 75
# Average Grade: 81.5
# ------------------------

# %%
#8.Email Management Create a class representing an email with attributes like sender, recipient, and subject. Implement methods to send an email and display email details


class Email:
  def __init__(self,sender,recipient,subject,body=" "):
    self.sender = sender
    self.recipient = recipient
    self.subject = subject
    self.body = body

  def send_email(self):
    print(f"Email sent from {self.sender} to {self.recipient} with subject '{self.subject}'")
    print("Body: ")
    print(self.body)

  def display_email_details(self):
    print("Email Details: ")
    print(f"Sender: {self.recipient}")
    print(f"Recipient: {self.subject}")
    print("_ _ _ _ _ ")


email1 = Email(sender="user1@.com" ,recipient="user2@.com", subject="Meet Tomarrow",body="Hii..let's meet at 1 PM tomorrow.")
email2 = Email(sender="user3@.com",recipient="user1@.com",subject="Project Update")

email1.display_email_details()
email1.send_email()

email2.display_email_details()
# Out:
# Email Details:
# Sender: user2@.com
# Recipient: Meet Tomarrow
# _ _ _ _ _
# Email sent from user1@.com to user2@.com with subject 'Meet Tomarrow'
# Body:
# Hii..let's meet at 1 PM tomorrow.
# Email Details:
# Sender: user1@.com
# Recipient: Project Update
# _ _ _ _ _

# %%
#9.Social Media Profile Create a class representing a social media profile with attributes like username and posts. Implement methods to add posts, display posts, and search for posts by keyword



class SocialMediaProfile:
    def __init__(self, username):
        self.username = username
        self.posts = []

    def add_post(self, post_content):
        self.posts.append(post_content)
        print(f"Post added to {self.username}'s profile.")

    def display_posts(self):
        if not self.posts:
            print(f"{self.username}'s profile has no posts.")
        else:
            print(f"{self.username}'s Posts:")
            for i, post in enumerate(self.posts, start=1):
                print(f"{i}. {post}")
            print("------------------------")

    def search_posts_by_keyword(self, keyword):
        matching_posts = [post for post in self.posts if keyword.lower() in post.lower()]
        if not matching_posts:
            print(f"No posts matching the keyword '{keyword}' found in {self.username}'s profile.")
        else:
            print(f"Posts in {self.username}'s profile containing the keyword '{keyword}':")
            for i, post in enumerate(matching_posts, start=1):
                print(f"{i}. {post}")
            print("------------------------")


profile1 = SocialMediaProfile(username="Yash_Gaikwad")
profile2 = SocialMediaProfile(username="Omkar_yadav")

profile1.add_post("Enjoying a sunny day at the beach!")
profile1.add_post("Just had a great workout at the gym.")

profile2.add_post("Trying out a new recipe for dinner.")
profile2.add_post("Watching a movie with friends.")

profile1.display_posts()
profile2.display_posts()

profile1.search_posts_by_keyword("beach")
profile2.search_posts_by_keyword("movie")
# Out:
# Post added to Yash_Gaikwad's profile.
# Post added to Yash_Gaikwad's profile.
# Post added to Okar_yadav's profile.
# Post added to Okar_yadav's profile.
# Yash_Gaikwad's Posts:
# 1. Enjoying a sunny day at the beach!
# 2. Just had a great workout at the gym.
# ------------------------
# Okar_yadav's Posts:
# 1. Trying out a new recipe for dinner.
# 2. Watching a movie with friends.
# ------------------------
# Posts in Yash_Gaikwad's profile containing the keyword 'beach':
# 1. Enjoying a sunny day at the beach!
# ------------------------
# Posts in Okar_yadav's profile containing the keyword 'movie':
# 1. Watching a movie with friends.
# ------------------------

# %%
#10.ToDo List Create a class representing a ToDo list with attributes like tasks and due dates. Implement methods to add tasks, mark tasks as completed, and display pending tasks


class ToDoList:
    def __init__(self):
        self.tasks = []

    def add_task(self, task, due_date=None):
        self.tasks.append({"task": task, "due_date": due_date, "completed": False})
        print(f"Task '{task}' added to the ToDo list.")

    def mark_task_as_completed(self, task_index):
        if 0 <= task_index < len(self.tasks):
            self.tasks[task_index]["completed"] = True
            print(f"Task '{self.tasks[task_index]['task']}' marked as completed.")
        else:
            print("Invalid task index.")

    def display_pending_tasks(self):
        pending_tasks = [task for task in self.tasks if not task["completed"]]
        if not pending_tasks:
            print("No pending tasks.")
        else:
            print("Pending Tasks:")
            for i, task in enumerate(pending_tasks, start=1):
                print(f"{i}. {task['task']} (Due Date: {task['due_date']})")
            print("------------------------")


todo_list = ToDoList()

todo_list.add_task("Write report for work", due_date="2024-02-01")
todo_list.add_task("Buy groceries")
todo_list.add_task("Exercise for 30 minutes", due_date="2024-02-10")

todo_list.display_pending_tasks()

todo_list.mark_task_as_completed(1)

todo_list.display_pending_tasks()
# Out:
# Task 'Write report for work' added to the ToDo list.
# Task 'Buy groceries' added to the ToDo list.
# Task 'Exercise for 30 minutes' added to the ToDo list.
# Pending Tasks:
# 1. Write report for work (Due Date: 2024-02-01)
# 2. Buy groceries (Due Date: None)
# 3. Exercise for 30 minutes (Due Date: 2024-02-10)
# ------------------------
# Task 'Buy groceries' marked as completed.
# Pending Tasks:
# 1. Write report for work (Due Date: 2024-02-01)
# 2. Exercise for 30 minutes (Due Date: 2024-02-10)
# ------------------------
